# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import (
    Embedding, Dense, SimpleRNN, LSTM, Bidirectional, Flatten
)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from nltk.corpus import movie_reviews
from sklearn.model_selection import train_test_split

# %%
# 1 .데이터 로드
ids = movie_reviews.fileids()
reviews = [movie_reviews.raw(id) for id in ids]
categoris = [movie_reviews.categories(id)[0] for id in ids]
# 토큰화 및 정수 인코딩
max_word = 10000
tokenizer = Tokenizer(num_words=max_word, oov_token='UNK')
tokenizer.fit_on_texts(reviews)
# 텍스트를 시퀀스로 변환
x = tokenizer.texts_to_sequences(reviews)
# 시퀀스 패딩
maxlen = 500
x = pad_sequences(x,maxlen=maxlen,truncating='pre')
# 레이블 변환
label_dict = {'pos':1, 'neg':0}
y = np.array([label_dict[c] for c in categoris])
# 학습 테스트 데이터 분할
x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y, random_state=42,test_size=0.2)

# %%
# 2 .세가지 모델 구축 , 학습
# 시드고정(재현성)
np.random.seed(42)
tf.random.set_seed(42)
# 모델 성능
results = {}
# ------ model 1 baseline(Flatten + Dense)
model1 = Sequential([
    Embedding(max_word,32,input_length = maxlen),
    Flatten(),
    Dense(1,activation='sigmoid')
])
model1.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['acc'])
history1 = model1.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
score1 = model1.evaluate(x_test,y_test)
results['baseline'] = score1[1]
print(f'model1 정확도:{score1[1]:.4f}')

# ------ model 2 (SimpleRnn)
model2 = Sequential([
    Embedding(max_word,32,input_length = maxlen),
    SimpleRNN(32),
    Dense(32,activation='relu'),
    Dense(1,activation='sigmoid')
])
model2.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['acc'])
history2 = model2.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
score1 = model2.evaluate(x_test,y_test)
results['Simple_RNN'] = score1[1]
print(f'model2 정확도:{score1[1]:.4f}')

# ------ model 3 (Bidirectional LSTM)
model3 = Sequential([
    Embedding(max_word,64,input_length = maxlen),
    Bidirectional(LSTM(64)),    
    Dense(64,activation='relu'),
    Dense(1,activation='sigmoid')
])
model3.compile(optimizer = 'adam', loss = 'binary_crossentropy',metrics=['acc'])
history3 = model3.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
score1 = model3.evaluate(x_test,y_test)
results['Bidirectional_LSTM'] = score1[1]
print(f'model3 정확도:{score1[1]:.4f}')
# Out:
# Epoch 1/10
# c:\Users\playdata2\miniconda3\envs\LLM311\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - acc: 0.5047 - loss: 0.6929 - val_acc: 0.5594 - val_loss: 0.6893
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9664 - loss: 0.5898 - val_acc: 0.5844 - val_loss: 0.6844
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9797 - loss: 0.4418 - val_acc: 0.5906 - val_loss: 0.6709
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.9977 - loss: 0.2647 - val_acc: 0.5906 - val_loss: 0.6561
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9992 - loss: 0.1377 - val_acc: 0.6062 - val_loss: 0.6455
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 1.0000 - loss: 0.0750 - val_acc: 0.6219 - val_loss: 0.6414
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 1.0000 - loss: 0.0451 - val_acc: 0.6219 - val_loss: 0.6404
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 1.0000 - loss: 0.0298 - val_acc: 0.6250 - val_loss: 0.6389
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 1.0000 - loss: 0.0211 - val_acc: 0.6281 - val_loss: 0.6377
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 1.0000 - loss: 0.0158 - val_acc: 0.6281 - val_loss: 0.6373
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.6175 - loss: 0.6383
# model1 정확도:0.6175
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - acc: 0.4945 - loss: 0.6959 - val_acc: 0.4531 - val_loss: 0.6999
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - acc: 0.7828 - loss: 0.6235 - val_acc: 0.5094 - val_loss: 0.7229
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - acc: 0.9148 - loss: 0.4268 - val_acc: 0.4688 - val_loss: 0.8115
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - acc: 0.9883 - loss: 0.1303 - val_acc: 0.4938 - val_loss: 0.9609
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - acc: 0.9937 - loss: 0.0430 - val_acc: 0.5125 - val_loss: 1.0711
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - acc: 0.9977 - loss: 0.0178 - val_acc: 0.5125 - val_loss: 1.1743
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.9977 - loss: 0.0127 - val_acc: 0.5188 - val_loss: 1.2610
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - acc: 0.9992 - loss: 0.0057 - val_acc: 0.5063 - val_loss: 1.3292
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - acc: 1.0000 - loss: 0.0021 - val_acc: 0.5031 - val_loss: 1.3533
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - acc: 1.0000 - loss: 0.0015 - val_acc: 0.5250 - val_loss: 1.3865
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - acc: 0.5050 - loss: 1.4347
# model2 정확도:0.5050
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - acc: 0.5219 - loss: 0.6929 - val_acc: 0.5437 - val_loss: 0.6897
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 218ms/step - acc: 0.6594 - loss: 0.6388 - val_acc: 0.6344 - val_loss: 0.6490
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 220ms/step - acc: 0.8914 - loss: 0.3038 - val_acc: 0.7063 - val_loss: 0.6992
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 223ms/step - acc: 0.9664 - loss: 0.1025 - val_acc: 0.6656 - val_loss: 0.8827
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 228ms/step - acc: 0.9727 - loss: 0.0994 - val_acc: 0.6844 - val_loss: 1.0697
# Epoch 6/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - acc: 0.9648 - loss: 0.0981 - val_acc: 0.6969 - val_loss: 0.9888
# Epoch 7/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step - acc: 0.9969 - loss: 0.0173 - val_acc: 0.7375 - val_loss: 1.0607
# Epoch 8/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - acc: 0.9961 - loss: 0.0157 - val_acc: 0.6938 - val_loss: 1.0891
# Epoch 9/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 225ms/step - acc: 0.9984 - loss: 0.0066 - val_acc: 0.7406 - val_loss: 1.1228
# Epoch 10/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 9s 226ms/step - acc: 0.9977 - loss: 0.0116 - val_acc: 0.7563 - val_loss: 1.1180
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - acc: 0.7350 - loss: 1.1681
# model2 정확도:0.7350

# %%
# 3 .성능 비교 및 시각화

# %%
# 4 .예측 결과 분석

# %%
# 5 .학습결과 해석
